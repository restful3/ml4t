# %% [markdown]
# # Download and store STOOQ data

# %% [markdown]
# This notebook contains information on downloading the STOOQ stock and ETF price data that we use in [Chapter 09](../09_time_series_models) for a pairs trading strategy based on cointegration and [Chapter 11](../11_decision_trees_random_forests) for a long-short strategy using Random Forest return predictions.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
import requests
from io import BytesIO
from zipfile import ZipFile, BadZipFile

import numpy as np
import pandas as pd
import pandas_datareader.data as web
from sklearn.datasets import fetch_openml

pd.set_option('display.expand_frame_repr', False)

# %% [markdown]
# ## Set Data Store path

# %% [markdown]
# Modify the path to the `DATA_STORE` if you would like to store the data elsewhere and change the notebooks accordingly

# %%
# DATA_STORE = Path('assets.h5')

# %% [markdown]
# ## Stooq Historical Market Data

# %% [markdown]
# > Note that the below downloading details may change at any time as Stooq updates their website; if you encounter errors, please inspect their website and raise a GitHub issue to let us know so we can update the information.
#
# > Update 12/2020: please note that STOOQ will disable automatic downloads and require CAPTCHA starting Dec 10, 2020 so that the code that downloads and unpacks the zip files will no longer work; please navigate to their website [here](https://stooq.com/db/h/) for manual download.

# %% [markdown]
# ### Download price data

# %% [markdown]
# 1. Download **price data** for the selected combination of asset class, market and frequency from [the Stooq website](https://stooq.com/db/h/)
# 2. Store the result under `stooq` using the preferred folder structure outlined on the website. It has the structure: `/data/freq/market/asset_class`, such as `/data/daily/us/nasdaq etfs`.

# %% [markdown]
# [잘안되니 이방법으로 다운로드](https://github.com/stefan-jansen/machine-learning-for-trading/issues/214)

# %%
# !pwd
# Out:
# /home/restful3/workspaces/study/ml4t/source

# %%
stooq_path = Path('/home/restful3/datasets_bigpond/ml4t/stooq') 
if not stooq_path.exists():
    stooq_path.mkdir()

# %% [markdown]
# Use the symbol for the market you want to download price data for. In this book we'll be useing `us` and `jp`.

# %%
STOOQ_URL = 'https://stooq.com/db/d/?b='

# %%
# def download_price_data(market='us'):
#     data_url = f'd_{market}_txt'
#     response = requests.get(STOOQ_URL + data_url).content
#     with ZipFile(BytesIO(response)) as zip_file:
#         for i, file in enumerate(zip_file.namelist()):
#             if not file.endswith('.txt'):
#                 continue
#             local_file = stooq_path / file
#             local_file.parent.mkdir(parents=True, exist_ok=True)
#             with local_file.open('wb') as output:
#                 for line in zip_file.open(file).readlines():
#                     output.write(line)

# %%
def download_price_data(market='us'):
    data_file = f'd_{market}_txt.zip'
    # data_file = os.path.join("./stooq", data_file)
    data_file = os.path.join(stooq_path, data_file)
    print(data_file)
    if os.path.exists(data_file):
        print('extracting {}'.format(data_file))
        with ZipFile(data_file) as zip_file:
            for i, file in enumerate(zip_file.namelist()):
                if not file.endswith('.txt'):
                    continue
                local_file = stooq_path / file
                print('file: {}'.format(local_file))
                local_file.parent.mkdir(parents=True, exist_ok=True)
                with local_file.open('wb') as output:
                    for line in zip_file.open(file).readlines():
                        output.write(line)
    else: print('Could not find file: {}'.format(data_file))

# %%
import os

# %%
for market in ['us', 'jp']:
    download_price_data(market=market)
# Out:
# /home/restful3/datasets_bigpond/ml4t/stooq/d_us_txt.zip
# extracting /home/restful3/datasets_bigpond/ml4t/stooq/d_us_txt.zip
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/us/nasdaq etfs
jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9776.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9778.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9780.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9782.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9783.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9787.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9788.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9790.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9791.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9793.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9795.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9799.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9812.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9816.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9818.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9820.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9823.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9824.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9827.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9828.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9830.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9831.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9832.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9835.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9837.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9842.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9843.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9845.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9846.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9849.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9850.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9852.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9853.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9854.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9856.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9857.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9861.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9867.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9869.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9872.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9873.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9876.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9878.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9880.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9882.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9885.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9887.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9888.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9889.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9890.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9895.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9896.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9900.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9902.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9903.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9904.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9906.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9908.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9913.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9914.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9919.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9927.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9928.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9929.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9930.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9932.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9934.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9936.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9941.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9946.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9948.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9950.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9955.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9956.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9959.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9960.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9962.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9969.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9972.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9973.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9974.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9976.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9977.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9978.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9979.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9980.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9982.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9983.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9984.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9986.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9987.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9989.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9990.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9991.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9993.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9994.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9995.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9996.jp.txt
# file: /home/restful3/datasets_bigpond/ml4t/stooq/data/daily/jp/tse stocks/2/9997.jp.txt

# %% [markdown]
# ### Add symbols

# %% [markdown]
# Add the corresponding **symbols**, i.e., tickers and names by following the directory tree on the same site. You can also adapt the following code snippet using the appropriate asset code that you find by inspecting the url; this example works for NASDAQ ETFs that have code `g=69`:
# ```python
# df = pd.read_csv('https://stooq.com/db/l/?g=69', sep='        ').apply(lambda x: x.str.strip())
# df.columns = ['ticker', 'name']
# df.drop_duplicates('ticker').to_csv('stooq/data/tickers/us/nasdaq etfs.csv', index=False)
# ```

# %%
metadata_dict = {
    ('jp', 'tse etfs'): 34,
    ('jp', 'tse stocks'): 32,
    ('us', 'nasdaq etfs'): 69,
    ('us', 'nasdaq stocks'): 27,
    ('us', 'nyse etfs'): 70,
    ('us', 'nyse stocks'): 28,
    ('us', 'nysemkt stocks'): 26
}

# %%
stooq_path
# Out:
# PosixPath('/home/restful3/datasets_bigpond/ml4t/stooq')

# %%
for (market, asset_class), code in metadata_dict.items():
    date_file = os.path.join(stooq_path, f'{code}.txt')
    df = pd.read_csv(date_file, sep='        ').apply(lambda x: x.str.strip())
    df.columns = ['ticker', 'name']
    df = df.drop_duplicates('ticker').dropna()
    print(market, asset_class, f'# tickers: {df.shape[0]:,.0f}')
    path = stooq_path / 'tickers' / market
    if not path.exists():
        path.mkdir(parents=True)
    df.to_csv(path / f'{asset_class}.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 3
#       1 for (market, asset_class), code in metadata_dict.items():
#       2     date_file = os.path.join(stooq_path, f'{code}.txt')
# ----> 3     df = pd.read_csv(date_file, sep='        ').apply(lambda x: x.str.strip())
#       4     df.columns = ['ticker', 'name']
#       5     df = df.drop_duplicates('ticker').dropna()
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/anaconda3/envs/trading/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/restful3/datasets_bigpond/ml4t/stooq/34.txt'

# %%
# for (market, asset_class), code in metadata_dict.items():
#     df = pd.read_csv(f'https://stooq.com/db/l/?g={code}', sep='        ').apply(lambda x: x.str.strip())
#     df.columns = ['ticker', 'name']
#     df = df.drop_duplicates('ticker').dropna()
#     print(market, asset_class, f'# tickers: {df.shape[0]:,.0f}')
#     path = stooq_path / 'tickers' / market
#     if not path.exists():
#         path.mkdir(parents=True)
#     df.to_csv(path / f'{asset_class}.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\python_parser.py:404, in PythonParser._infer_columns(self)
#     403 try:
# --> 404     line = self._buffered_line()
#     406     while self.line_pos <= hr:
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\python_parser.py:637, in PythonParser._buffered_line(self)
#     636 else:
# --> 637     return self._next_line()
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\python_parser.py:738, in PythonParser._next_line(self)
#     737 while True:
# --> 738     orig_line = self._next_iter_line(row_num=self.pos + 1)
#     739     self.pos += 1
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\python_parser.py:805, in PythonParser._next_iter_line(self, row_num)
#     804 assert self.data is not None
# --> 805 line = next(self.data)
#     806 # for mypy
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# EmptyDataError                            Traceback (most recent call last)
# Cell In[55], line 2
#       1 for (market, asset_class), code in metadata_dict.items():
# ----> 2     df = pd.read_csv(f'https://stooq.com/db/l/?g={code}', sep='        ').apply(lambda x: x.str.strip())
#       3     df.columns = ['ticker', 'name']
#       4     df = df.drop_duplicates('ticker').dropna()
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\python_parser.py:133, in PythonParser.__init__(self, f, **kwds)
#     127 self._col_indices: list[int] | None = None
#     128 columns: list[list[Scalar | None]]
#     129 (
#     130     columns,
#     131     self.num_original_columns,
#     132     self.unnamed_cols,
# --> 133 ) = self._infer_columns()
#     135 # Now self.columns has the set of columns that we will process.
#     136 # The original set is stored in self.original_columns.
#     137 # error: Cannot determine type of 'index_names'
#     138 (
#     139     self.columns,
#     140     self.index_names,
#    (...)
#     145     self.index_names,  # type: ignore[has-type]
#     146 )
#
# File E:\miniconda\envs\qt\lib\site-packages\pandas\io\parsers\python_parser.py:432, in PythonParser._infer_columns(self)
#     429         return columns, num_original_columns, unnamed_cols
#     431     if not self.names:
# --> 432         raise EmptyDataError("No columns to parse from file") from err
#     434     line = self.names[:]
#     436 this_columns: list[Scalar | None] = []
#
# EmptyDataError: No columns to parse from file

# %% [markdown]
# ### Store price data in HDF5 format

# %% [markdown]
# To speed up loading, we store the price data in HDF format. The function `get_stooq_prices_and_symbols` loads data assuming the directory structure described above and takes the following arguments:
# - frequency (see Stooq website for options as these may change; default is `daily`
# - market (default: `us`), and
# - asset class (default: `nasdaq etfs`.
#
# It removes files that do not have data or do not appear in the corresponding list of symbols.

# %%
def get_stooq_prices_and_tickers(frequency='daily',
                                 market='us',
                                 asset_class='nasdaq etfs'):
    prices = []
    
    tickers = (pd.read_csv(stooq_path / 'tickers' / market / f'{asset_class}.csv'))

    if frequency in ['5 min', 'hourly']:
        parse_dates = [['date', 'time']]
        date_label = 'date_time'
    else:
        parse_dates = ['date']
        date_label = 'date'
    names = ['ticker', 'freq', 'date', 'time', 
             'open', 'high', 'low', 'close','volume', 'openint']
    
    usecols = ['ticker', 'open', 'high', 'low', 'close', 'volume'] + parse_dates
    path = stooq_path / 'data' / frequency / market / asset_class
    print(path.as_posix())
    files = path.glob('**/*.txt')
    for i, file in enumerate(files, 1):
        if i % 500 == 0:
            print(i)
        if file.stem not in set(tickers.ticker.str.lower()):
            print(file.stem, 'not available')
            file.unlink()
        else:
            try:
                df = (pd.read_csv(
                    file,
                    names=names,
                    usecols=usecols,
                    header=0,
                    parse_dates=parse_dates))
                prices.append(df)
            except pd.errors.EmptyDataError:
                print('\tdata missing', file.stem)
                file.unlink()

    prices = (pd.concat(prices, ignore_index=True)
              .rename(columns=str.lower)
              .set_index(['ticker', date_label])
              .apply(lambda x: pd.to_numeric(x, errors='coerce')))
    return prices, tickers

# %% [markdown]
# We'll be using US equities and ETFs in [Chapter 9](../09_time_series_models) and and Japanese equities in [Chapter 11](../11_decision_trees_random_forests). The following code collects the price data for the period 2000-2019 and stores it with the corresponding symbols in the global `assets.h5` store:

# %%
# load some Japanese and all US assets for 2000-2019
markets = {'jp': ['tse stocks'],
           'us': ['nasdaq etfs', 'nasdaq stocks', 'nyse etfs', 'nyse stocks', 'nysemkt stocks']
          }
frequency = 'daily'

idx = pd.IndexSlice
for market, asset_classes in markets.items():
    for asset_class in asset_classes:
        print(f'\n{asset_class}')
        prices, tickers = get_stooq_prices_and_tickers(frequency=frequency, 
                                                       market=market, 
                                                       asset_class=asset_class)
        
        prices = prices.sort_index().loc[idx[:, '2010': '2023'], :]
        names = prices.index.names
        prices = (prices
                  .reset_index()
                  .drop_duplicates()
                  .set_index(names)
                  .sort_index())
        
        print('\nNo. of observations per asset')
        print(prices.groupby('ticker').size().describe())
        key = f'stooq/{market}/{asset_class.replace(" ", "/")}/'
        
        # print(prices.info(null_counts=True))
        
        prices.to_hdf(DATA_STORE, key + 'prices', format='t')
        
        print(tickers.info())
        tickers.to_hdf(DATA_STORE, key + 'tickers', format='t')
# Out:
# tse stocks
# stooq/data/daily/jp/tse stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
#
# No. of observations per asset
# count    3895.000000
# mean     2669.281386
# std      1099.839997
# min         1.000000
# 25%      2117.000000
# 50%      3376.000000
# 75%      3424.000000
# max      3425.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  3900 non-null   object
#  1   name    3900 non-null   object
# dtypes: object(2)
# memory usage: 61.1+ KB
# None
#
# nasdaq etfs
# stooq/data/daily/us/nasdaq etfs
#
# No. of observations per asset
# count     354.000000
# mean     2312.937853
# std       986.890548
# min        89.000000
# 25%      1464.750000
# 50%      2353.500000
# 75%      3345.500000
# max      3522.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker  357 non-null    object
#  1   name    357 non-null    object
# dtypes: object(2)
# memory usage: 5.7+ KB
# None
#
# nasdaq stocks
# stooq/data/daily/us/nasdaq stocks
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# satlw.us not available
# 4000
# vsacw.us not available
# 4500
#
# No. of observations per asset
# count    4297.000000
# mean     1588.929718
# std      1303.615852
# min         1.000000
# 25%       479.000000
# 50%      1061.000000
# 75%      3167.000000
# max      3522.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4570 entries, 0 to 4569
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ticker