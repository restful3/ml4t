# %%
import os

# %%
with open('requirements.txt') as f:
    for line in f:
        package = line.strip()
        if package:
            print(f"Installing {package}...")
            os.system(f"pip install {package}")
# Out:
# Installing absl-py==1.3.0...
# WARNING: Ignoring invalid distribution -tsdangerous (/home/restful3/anaconda3/envs/trading/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -tsdangerous (/home/restful3/anaconda3/envs/trading/lib/python3.10/site-packages)
# Installing aiodns==2.0.0...
# WARNING: Ignoring invalid distribution -tsdangerous (/home/restful3/anaconda3/envs/trading/lib/python3.10/site-packages)
# ...
# WARNING: Ignoring invalid distribution -tsdangerous (/home/restful3/anaconda3/envs/trading/lib/python3.10/site-packages)
# Installing aiohttp==3.8.1...
# WARNING: Ignoring invalid distribution -tsdangerous (/home/restful3/anaconda3/envs/trading/lib/python3.10/site-packages)
# ...
#   Using cached aiohttp-3.8.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (7.3 kB)
# ...
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...
