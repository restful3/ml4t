# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.tsa.stattools as ts_stats
import statsmodels.tsa.vector_ar.vecm as vm

# %matplotlib inline
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['figure.dpi'] = 100


def calculateMaxDD(cumret):
    """최대 낙폭 계산"""
    vals = cumret.values if hasattr(cumret, 'values') else cumret
    highwatermark = np.zeros(len(vals))
    drawdown = np.zeros(len(vals))
    drawdownduration = np.zeros(len(vals))
    for t in range(1, len(vals)):
        highwatermark[t] = max(highwatermark[t-1], vals[t])
        drawdown[t] = (1 + vals[t]) / (1 + highwatermark[t]) - 1
        if drawdown[t] == 0:
            drawdownduration[t] = 0
        else:
            drawdownduration[t] = drawdownduration[t-1] + 1
    maxDD = np.min(drawdown)
    maxDDD = np.max(drawdownduration)
    return maxDD, maxDDD

# %% [markdown]
# # Chapter 5: 통화와 선물의 평균 회귀 (Mean Reversion of Currencies and Futures)
#
# ## 목차
#
# 1. [개요 및 문제 정의](#1.-개요-및-문제-정의)
# 2. [사용 데이터](#2.-사용-데이터)
# 3. [분석 1: AUD/USD vs CAD/USD 페어 트레이딩](#3.-분석-1)
# 4. [분석 2: AUD/CAD 롤오버 이자 전략](#4.-분석-2)
# 5. [분석 3: 선물 스팟/롤 수익률 추정](#5.-분석-3)
# 6. [분석 4: CL 캘린더 스프레드 평균 회귀](#6.-분석-4)
# 7. [분석 5: VX-ES 변동성 vs 주가지수 평균 회귀](#7.-분석-5)
# 8. [전략 종합 비교](#8.-전략-종합-비교)
# 9. [결론 및 권고사항](#9.-결론-및-권고사항)
#
# ---
#
# ## 1. 개요 및 문제 정의
#
# Chapter 5는 통화와 선물 시장에서의 평균 회귀 전략을 탐구한다. 전통적으로 모멘텀과 연관되는 시장에서도
# 특정 니치에서 활용 가능한 평균 회귀 기회를 발견한다.
#
# ### 핵심 수학적 개념
#
# **포트폴리오 수익률 (식 5.1):**
#
# $$r(t+1) = \frac{n_1 \cdot y_{1,U}(t) \cdot r_1(t+1) + n_2 \cdot y_{2,U}(t) \cdot r_2(t+1)}{|n_1| \cdot y_{1,U}(t) + |n_2| \cdot y_{2,U}(t)}$$
#
# **롤오버 이자 보정 초과 수익률 (식 5.6):**
#
# $$r(t+1) = \log(y_{B,Q}(t+1)) - \log(y_{B,Q}(t)) + \log(1 + i_B(t)) - \log(1 + i_Q(t))$$
#
# **선물 가격 모델 (식 5.7-5.10):**
#
# $$F(t, T) = S(t) \cdot e^{\gamma(t-T)}$$
#
# $$\frac{d(\log F)}{dt} = \alpha + \gamma \quad (\text{총 수익률 = 스팟 수익률 + 롤 수익률})$$
#
# ---
#
# ## 2. 사용 데이터
#
# | 파일명 | 내용 | 용도 |
# |--------|------|------|
# | `inputData_AUDUSD_20120426.csv` | AUD/USD 일일 종가 | 예제 5.1 |
# | `inputData_USDCAD_20120426.csv` | USD/CAD 일일 종가 | 예제 5.1 (역수 -> CAD/USD) |
# | `inputData_AUDCAD_20120426.csv` | AUD/CAD 일일 종가 | 예제 5.2 |
# | `AUD_interestRate.csv` | AUD 월별 금리 | 예제 5.2 롤오버 |
# | `CAD_interestRate.csv` | CAD 월별 금리 | 예제 5.2 롤오버 |
# | `inputDataDaily_C2_20120813.csv` | 옥수수 선물 30계약 + 스팟 | 예제 5.3 |
# | `inputDataDaily_CL_20120502.csv` | WTI 원유 선물 88계약 | 예제 5.4 |
# | `vix_utils` (CBOE CFE) | VX 선물 근월물 settle | 예제 5.5 |
# | `yfinance` ES=F | E-mini S&P 500 선물 | 예제 5.5 |

# %%
# === 데이터 로드 ===

# AUD/USD
audusd = pd.read_csv('inputData_AUDUSD_20120426.csv')
audusd['Date'] = pd.to_datetime(audusd['Date'], format='%Y%m%d')
audusd.set_index('Date', inplace=True)
print(f'AUD/USD: {len(audusd)} 데이터 포인트')

# USD/CAD
usdcad = pd.read_csv('inputData_USDCAD_20120426.csv')
usdcad['Date'] = pd.to_datetime(usdcad['Date'], format='%Y%m%d')
usdcad.set_index('Date', inplace=True)
print(f'USD/CAD: {len(usdcad)} 데이터 포인트')

# AUD/CAD
audcad = pd.read_csv('inputData_AUDCAD_20120426.csv')
audcad['Date'] = pd.to_datetime(audcad['Date'], format='%Y%m%d')
audcad.set_index('Date', inplace=True)
print(f'AUD/CAD: {len(audcad)} 데이터 포인트')

# 금리 데이터
aud_rate = pd.read_csv('AUD_interestRate.csv')
cad_rate = pd.read_csv('CAD_interestRate.csv')
print(f'AUD 금리: {len(aud_rate)} 월, CAD 금리: {len(cad_rate)} 월')

# 옥수수 선물
corn = pd.read_csv('inputDataDaily_C2_20120813.csv')
corn['Date'] = pd.to_datetime(corn['Date'], format='%Y%m%d')
corn.set_index('Date', inplace=True)
print(f'옥수수 선물: {len(corn)} 거래일 x {len(corn.columns)} 컬럼')

# WTI 원유 선물
cl = pd.read_csv('inputDataDaily_CL_20120502.csv')
cl['Date'] = pd.to_datetime(cl['Date'], format='%Y%m%d')
cl.set_index('Date', inplace=True)
print(f'WTI 원유 선물: {len(cl)} 거래일 x {len(cl.columns)} 컬럼')
# Out:
# AUD/USD: 862 데이터 포인트
# USD/CAD: 862 데이터 포인트
# AUD/CAD: 1237 데이터 포인트
# AUD 금리: 147 월, CAD 금리: 144 월
# 옥수수 선물: 6492 거래일 x 31 컬럼
# WTI 원유 선물: 2867 거래일 x 89 컬럼

# %% [markdown]
# ---
#
# ## 3. 분석 1: AUD/USD vs CAD/USD 페어 트레이딩 (예제 5.1)
#
# ### 방법론
#
# - AUD/USD와 CAD/USD(= 1/USD.CAD)를 공통 호가 통화(USD)로 맞춤
# - 250일 롤링 요한센 공적분 검정으로 동적 헤지 비율 산출
# - 20일 롤링 z-score 기반 선형 평균 회귀
#
# **핵심**: 공적분 검정 시 두 통화가 동일한 호가 통화를 공유해야 포인트 가치가 동일해진다.
#
# 책 결과: APR=6.45%, Sharpe=1.36

# %%
# === 분석 1: AUD/USD vs CAD/USD 페어 트레이딩 ===

# CAD/USD로 변환 (USD/CAD의 역수)
df1 = usdcad.copy()
df1.columns = ['CAD'] # USD/CAD -> CAD/USD
df1['CAD'] = 1.0 / df1['CAD']

df2 = audusd.copy()
df2.columns = ['AUD'] # AUD/USD

df_fx = pd.merge(df1, df2, left_index=True, right_index=True, how='inner')
print(f'공통 거래일: {len(df_fx)}')

trainlen = 250
lookback = 20

hedgeRatio = np.full(df_fx.shape, np.nan)
numUnits = np.full(df_fx.shape[0], np.nan)

# 250일 롤링 요한센 + z-score
for t in range(trainlen + 1, df_fx.shape[0]):
    result = vm.coint_johansen(df_fx.values[(t - trainlen - 1):t - 1], det_order=0, k_ar_diff=1)
    hedgeRatio[t, :] = result.evec[:, 0] # 첫 번째 공적분 벡터 예: [0.8, -1.2]이면 "CAD 0.8 단위 + AUD -1.2 단위"로 합성 포트폴리오를 만들라는 뜻
    yport = np.dot(df_fx.values[(t - lookback):t], result.evec[:, 0]) # 최근 20일 간의 가격에 헤지 비율을 곱해서 스프레드 시계열 생성
    ma = np.mean(yport)
    mstd = np.std(yport, ddof=1)
    if mstd > 0:
        numUnits[t] = -(yport[-1] - ma) / mstd # z-score 계산: (현재 스프레드 - 평균) / 표준편차. 음수면 "스프레드가 평균보다 낮으니 매수"라는 뜻

# 포지션 및 수익률 계산
pos_arr = np.expand_dims(numUnits, axis=1) * hedgeRatio * df_fx.values # 각 시점의 포지션 = z-score에 따른 거래 단위 * 헤지 비율 * 가격. 예: numUnits=100, hedgeRatio=[0.8, -1.2], 가격=[1.5, 1.0]이면 "CAD 80 단위 매수 + AUD 120 단위 매도"라는 뜻
pos_shift = np.full_like(pos_arr, np.nan)
pos_shift[1:] = pos_arr[:-1] # 포지션을 하루씩 뒤로 이동: 오늘의 포지션이 내일의 수익률에 영향을 주므로, 수익률 계산 시 어제의 포지션을 사용하기 위함
pnl = np.nansum(pos_shift * df_fx.pct_change().values, axis=1) # 수익률 계산: 포지션 * 가격 변화율의 합. 예: "CAD 80 단위 매수 + AUD 120 단위 매도"에서 CAD가 1% 상승하고 AUD가 0.5% 하락하면 "80 * 0.01 + (-120) * (-0.005) = 0.8 + 0.6 = 1.4"라는 뜻
denom = np.nansum(np.abs(pos_shift), axis=1) # 수익률을 포지션 규모로 나누기 위해 포지션의 절대값 합 계산. 예: "CAD 80 단위 매수 + AUD 120 단위 매도"이면 "abs(80) + abs(-120) = 200"이라는 뜻. 이렇게 하면 수익률이 "포지션 규모 대비 얼마인지"로 표현됨
denom[denom == 0] = np.nan # 포지션이 없는 날은 수익률 계산에서 제외하기 위해 0인 경우 NaN으로 처리. 예: 포지션이 없으면 수익률도 0이 아니라 계산에서 제외되어야 하므로 NaN으로 설정
ret_arr = pnl / denom # 최종 수익률 계산: 포지션 규모 대비 수익률. 예: pnl이 1.4이고 denom이 200이면 "1.4 / 200 = 0.007"即 "0.7% 수익률"이라는 뜻

valid_mask = np.isfinite(ret_arr) # 수익률 배열에서 유효한 값(포지션이 있었던 날의 수익률)만 선택하기 위한 마스크. 예: 포지션이 없었던 날은 ret_arr가 NaN이므로, 유효한 수익률만 계산에 포함시키기 위해 isfinite 함수를 사용하여 True/False 마스크 생성
ret_fx = pd.Series(ret_arr[valid_mask], index=df_fx.index[valid_mask]) # 유효한 수익률만 시리즈로 변환하여 날짜 인덱스와 함께 저장. 예: 포지션이 있었던 날의 수익률만 ret_fx라는 시리즈로 만들어서 날짜와 함께 분석에 사용하기 위함
cumret_fx = (1 + ret_fx).cumprod() - 1 # 누적 수익률 계산: (1 + 일별 수익률)의 누적 곱에서 1을 빼면 전체 기간 동안의 총 수익률이 나옴. 예: 일별 수익률이 [0.01, -0.005, 0.02]이면 "누적 수익률 = (1 + 0.01) * (1 - 0.005) * (1 + 0.02) - 1"이라는 뜻

apr_fx = np.prod(1 + ret_fx.values) ** (252 / len(ret_fx)) - 1 # 연간 수익률 계산: (1 + 전체 수익률)^(연간 거래일 수 / 실제 거래일 수) - 1. 예: 전체 수익률이 0.5이고 실제 거래일이 100일이면 "연간 수익률 = (1 + 0.5)^(252 / 100) - 1"이라는 뜻
sharpe_fx = np.sqrt(252) * np.mean(ret_fx.values) / np.std(ret_fx.values) # 샤프 비율 계산: (평균 수익률 / 수익률의 표준편차) * sqrt(연간 거래일 수). 예: 평균 수익률이 0.001이고 표준편차가 0.01이면 "샤프 비율 = (0.001 / 0.01) * sqrt(252)"이라는 뜻
maxDD_fx, maxDDD_fx = calculateMaxDD(cumret_fx) # 최대 낙폭과 낙폭 기간 계산: calculateMaxDD 함수는 누적 수익률 시리즈를 입력으로 받아 최대 낙폭과 그 기간을 반환. 예: 누적 수익률이 0.5에서 0.3으로 떨어지는 경우 최대 낙폭은 -0.2 (즉, 20% 손실)이고, 낙폭 기간은 이 손실이 지속된 일수

print(f'APR      = {apr_fx*100:.2f}%')
print(f'Sharpe   = {sharpe_fx:.4f}')
print(f'Max DD   = {maxDD_fx*100:.2f}%')
print(f'(책 기대값: APR=6.45%, Sharpe=1.36)')
# Out:
# 공통 거래일: 862
# APR      = 9.24%
# Sharpe   = 1.3629
# Max DD   = -4.89%
# (책 기대값: APR=6.45%, Sharpe=1.36)

# %% [markdown]
# ### 결과
#
# | 지표 | 값 | 책 기대값 |
# |------|-----|----------|
# | APR | 9.24% | 6.45% |
# | Sharpe Ratio | 1.3629 | 1.36 |
# | Max Drawdown | -4.89% | - |

# %%
# === AUD-CAD 페어 트레이딩 차트 ===

fig, axes = plt.subplots(2, 1, figsize=(12, 8))

axes[0].plot(cumret_fx.index, cumret_fx.values * 100, 'b-', linewidth=1)
axes[0].set_title('AUD/USD vs CAD/USD Pair Trading (Johansen) - Cumulative Returns', fontsize=13)
axes[0].set_ylabel('Cumulative Return (%)')
axes[0].grid(True, alpha=0.3)

axes[1].plot(df_fx.index, df_fx['AUD'].values, label='AUD/USD', linewidth=0.8)
axes[1].plot(df_fx.index, df_fx['CAD'].values, label='CAD/USD', linewidth=0.8)
axes[1].set_title('AUD/USD and CAD/USD Prices', fontsize=13)
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 4. 분석 2: AUD/CAD 롤오버 이자 전략 (예제 5.2)
#
# ### 방법론
#
# - AUD/CAD 직접 크로스레이트에 단순 선형 평균 회귀
# - 롤오버 이자 반영: AUD(T+2, 수요일 3x) / CAD(T+1, 목요일 3x)
# - 롤오버 포함/미포함 성과 비교

# %%
# === 분석 2: AUD/CAD 롤오버 이자 전략 ===

df_ac = audcad.copy()
df_ac.columns = ['Close']

# 금리 데이터를 날짜 인덱스로 변환
def rate_to_daily(rate_df, currency):
    rate_df = rate_df.copy()
    rate_df['Date'] = pd.to_datetime(
        rate_df['Year'].astype(str) + rate_df['Month'].astype(str).str.zfill(2) + '01',
        format='%Y%m%d'
    )
    rate_df.set_index('Date', inplace=True)
    rate_df = rate_df[['Rates']]
    rate_df.columns = [f'{currency}_rate']
    return rate_df

aud_r = rate_to_daily(aud_rate, 'AUD')
cad_r = rate_to_daily(cad_rate, 'CAD')

# 일일 데이터로 forward-fill
df_ac = df_ac.join(aud_r, how='left')
df_ac = df_ac.join(cad_r, how='left')
df_ac['AUD_rate'] = df_ac['AUD_rate'].ffill()
df_ac['CAD_rate'] = df_ac['CAD_rate'].ffill()

# 연율 -> 일율 변환
df_ac['AUD_daily'] = df_ac['AUD_rate'] / 100 / 365
df_ac['CAD_daily'] = df_ac['CAD_rate'] / 100 / 365

# 3x 롤오버: AUD 수요일(2), CAD 목요일(3)
df_ac['DayOfWeek'] = df_ac.index.dayofweek # 월요일=0, 화요일=1, 수요일=2, 목요일=3, 금요일=4
df_ac['AUD_rollover'] = df_ac['AUD_daily']
df_ac.loc[df_ac['DayOfWeek'] == 2, 'AUD_rollover'] = df_ac['AUD_daily'] * 3 # 수요일에는 AUD 롤오버 이자가 3배가 됨
df_ac['CAD_rollover'] = df_ac['CAD_daily']
df_ac.loc[df_ac['DayOfWeek'] == 3, 'CAD_rollover'] = df_ac['CAD_daily'] * 3 # 목요일에는 CAD 롤오버 이자가 3배가 됨

lookback_ac = 20

# z-score
ma_ac = df_ac['Close'].rolling(lookback_ac).mean()
mstd_ac = df_ac['Close'].rolling(lookback_ac).std()
zScore_ac = (df_ac['Close'] - ma_ac) / mstd_ac
numUnits_ac = -np.sign(zScore_ac).fillna(0)

# 롤오버 이자 포함 수익률
log_close = np.log(df_ac['Close']) # 로그 수익률 계산을 위해 가격을 로그로 변환
ret_with = numUnits_ac.shift(1) * (
    log_close.diff() +
    np.log(1 + df_ac['AUD_rollover']) - np.log(1 + df_ac['CAD_rollover'])
) # 포지션이 하루씩 뒤로 이동한 상태에서, 가격 변화와 롤오버 이자 차이를 합산하여 수익률 계산. 예: "포지션이 어제 매수였다면 오늘의 수익률은 (오늘의 로그 가격 변화 + 오늘의 AUD 롤오버 이자 - 오늘의 CAD 롤오버 이자) * 어제의 포지션"이라는 뜻
ret_with = ret_with.iloc[lookback_ac:].fillna(0)
cumret_with = (1 + ret_with).cumprod() - 1
apr_with = (1 + ret_with).prod() ** (252/len(ret_with)) - 1 # 연간 수익률 계산: (1 + 전체 수익률)^(연간 거래일 수 / 실제 거래일 수) - 1. 예: 전체 수익률이 0.5이고 실제 거래일이 100일이면 "연간 수익률 = (1 + 0.5)^(252 / 100) - 1"이라는 뜻
sharpe_with = np.sqrt(252) * ret_with.mean() / ret_with.std()

# 롤오버 이자 미포함 수익률
ret_without = numUnits_ac.shift(1) * log_close.diff() # 포지션이 하루씩 뒤로 이동한 상태에서, 가격 변화만으로 수익률 계산. 예: "포지션이 어제 매수였다면 오늘의 수익률은 (오늘의 로그 가격 변화) * 어제의 포지션"이라는 뜻
ret_without = ret_without.iloc[lookback_ac:].fillna(0)
cumret_without = (1 + ret_without).cumprod() - 1
apr_without = (1 + ret_without).prod() ** (252/len(ret_without)) - 1
sharpe_without = np.sqrt(252) * ret_without.mean() / ret_without.std()

avg_rate_diff = (df_ac['AUD_rate'] - df_ac['CAD_rate']).mean()

print(f'[롤오버 이자 포함]  APR = {apr_with*100:.2f}%, Sharpe = {sharpe_with:.4f}')
print(f'[롤오버 이자 미포함] APR = {apr_without*100:.2f}%, Sharpe = {sharpe_without:.4f}')
print(f'평균 금리차 (AUD - CAD) = {avg_rate_diff:.2f}% 연율')
print(f'(책 기대값: 6.2%/0.54 vs 6.7%/0.58)')
# Out:
# [롤오버 이자 포함]  APR = 6.28%, Sharpe = 0.5483
# [롤오버 이자 미포함] APR = 6.83%, Sharpe = 0.5893
# 평균 금리차 (AUD - CAD) = 3.36% 연율
# (책 기대값: 6.2%/0.54 vs 6.7%/0.58)

# %% [markdown]
# ### 결과
#
# | 지표 | 롤오버 포함 | 롤오버 미포함 | 책 기대값 |
# |------|-----------|------------|----------|
# | APR | 6.28% | 6.83% | 6.2% / 6.7% |
# | Sharpe | 0.5483 | 0.5893 | 0.54 / 0.58 |
#
# 평균 금리차 (AUD - CAD): 3.36% 연율
#
# **통찰**: 연간 ~5%의 롤오버 이자에도 불구하고 단기 전략에서는 영향이 미미하다.

# %%
# === AUD/CAD 롤오버 비교 차트 ===

fig, ax = plt.subplots(1, 1, figsize=(12, 5))
ax.plot(cumret_with.index, cumret_with.values * 100, 'b-', linewidth=1, label='With Rollover')
ax.plot(cumret_without.index, cumret_without.values * 100, 'r--', linewidth=1, label='Without Rollover')
ax.set_title('AUD/CAD Mean Reversion with/without Rollover Interest', fontsize=13)
ax.set_ylabel('Cumulative Return (%)')
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 5. 분석 3: 선물 스팟/롤 수익률 추정 (예제 5.3)
#
# ### 방법론
#
# - **스팟 수익률(alpha)**: log(스팟 가격) ~ 시간 선형 회귀의 기울기 x 252
# - **롤 수익률(gamma)**: 매일 가장 가까운 5개 연속 계약의 log(가격) ~ 만기까지 월수 회귀, gamma = -12 x 기울기
#
# 책 결과: alpha=+2.8%, gamma=-12.8%

# %%
# === 분석 3: 옥수수 선물 스팟/롤 수익률 추정 ===

# 스팟 컬럼 분리
spot = corn['C_Spot']
df_futures = corn.drop('C_Spot', axis=1)

# 스팟 수익률 (alpha)
T_reg = sm.add_constant(range(spot.shape[0]))
model_spot = sm.OLS(np.log(spot), T_reg) # 스팟 가격의 로그를 시간에 대해 회귀 분석하여 일일 알파 추정.
res_spot = model_spot.fit() # 회귀 분석 결과에서 기울기(시간에 따른 로그 가격 변화율)를 추출하여 일일 알파로 사용. 
alpha_annual = 252 * res_spot.params.iloc[1]

print(f'[스팟 수익률]')
print(f'  일일 알파 = {res_spot.params.iloc[1]:.6f}')
print(f'  연율 알파 = {alpha_annual*100:.2f}%')

# 롤 수익률 (gamma)
gamma_corn = np.full(df_futures.shape[0], np.nan)
for t in range(df_futures.shape[0]):
    idx = np.where(np.isfinite(df_futures.iloc[t, :]))[0]
    idxDiff = np.roll(idx, -1) - idx
    all_ones = all(idxDiff[0:4] == 1)
    if (len(idx) >= 5) and all_ones: 
        FT = df_futures.iloc[t, idx[:5]] # 롤 수익률 추정 시점에서 유효한 선물 가격이 5개 이상이고, 
        T_ft = sm.add_constant(np.arange(FT.shape[0])) # 이들이 연속된 인덱스(예: 0,1,2,3,4)인 경우에만 회귀 분석 수행.
        model_ft = sm.OLS(np.log(FT.values), T_ft) # 선물 가격의 로그를 시간에 대해 회귀 분석하여 롤 수익률 추정
        res_ft = model_ft.fit() # 회귀 분석 결과에서 기울기(시간에 따른 로그 가격 변화율)를 추출하여 일일 감마로 사용. 
        gamma_corn[t] = -12 * res_ft.params[1] # 선물 가격의 일일 변화율 * 12"로 계산하여 연율화. 음수 부호는 롤 수익률이 선물 가격의 상승과 반대로 움직이는 경향이 있기 때문.

mean_gamma = np.nanmean(gamma_corn)
n_valid = np.sum(np.isfinite(gamma_corn))

print(f'[롤 수익률]')
print(f'  평균 연율 감마 = {mean_gamma*100:.2f}%')
print(f'  감마 추정 일수 = {n_valid}')
print(f'  (책 기대값: 알파=+2.8%, 감마=-12.8%)')
# Out:
# [스팟 수익률]
#   일일 알파 = 0.000111
#   연율 알파 = 2.81%
# [롤 수익률]
#   평균 연율 감마 = -12.78%
#   감마 추정 일수 = 1570
#   (책 기대값: 알파=+2.8%, 감마=-12.8%)

# %% [markdown]
# ### 결과 (옥수수 선물)
#
# | 지표 | 값 | 책 기대값 |
# |------|-----|----------|
# | 스팟 수익률 (alpha) | 2.81% | +2.8% |
# | 롤 수익률 (gamma) | -12.78% | -12.8% |
#
# **핵심 통찰**: BR, C, TU 등에서 롤 수익률의 크기가 스팟 수익률을 압도한다.
# 스팟 가격의 평균 회귀가 선물 가격의 평균 회귀를 의미하지 않는다.

# %%
# === 선물 수익률 차트 ===

fig, axes = plt.subplots(2, 1, figsize=(12, 8))

axes[0].plot(corn.index, spot.values, 'b-', linewidth=0.8)
axes[0].set_title('Corn Spot Price', fontsize=13)
axes[0].set_ylabel('Price (cents/bushel)')
axes[0].grid(True, alpha=0.3)

valid_idx = np.where(np.isfinite(gamma_corn))[0]
axes[1].plot(corn.index[valid_idx], gamma_corn[valid_idx] * 100, 'r-', linewidth=0.5, alpha=0.7)
axes[1].axhline(y=mean_gamma*100, color='k', linewidth=1, linestyle='--', label=f'Mean: {mean_gamma*100:.1f}%')
axes[1].set_title('Corn Roll Return (Gamma, annualized)', fontsize=13)
axes[1].set_ylabel('Roll Return (%)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 6. 분석 4: CL 캘린더 스프레드 평균 회귀 (예제 5.4)
#
# ### 방법론
#
# 1. CL 선물 포워드 커브에서 매일 감마(롤 수익률) 계산
# 2. 감마의 ADF 검정으로 정상성 확인
# 3. 반감기 계산 -> z-score 룩백으로 사용
# 4. 근월-원월(12개월) 스프레드 포지션, z-score로 방향 결정
#
# 책 결과: APR=2.4%, Sharpe=1.28, 반감기=41일

# %%
# === 분석 4: CL 캘린더 스프레드 평균 회귀 ===

# 감마 계산
gamma_cl = np.full(cl.shape[0], np.nan)
for t in range(cl.shape[0]):
    idx = np.where(np.isfinite(cl.iloc[t, :]))[0]
    idxDiff = np.array(list(set(idx[1:]) - set(idx)))
    if (len(idx) >= 5) and (all(idxDiff[0:4] == 1)):
        FT = cl.iloc[t, idx[:5]]
        T_ft = sm.add_constant(np.arange(FT.shape[0]))
        model_ft = sm.OLS(np.log(FT.values), T_ft)
        res_ft = model_ft.fit()
        gamma_cl[t] = -12 * res_ft.params[1]

# ADF 검정
gamma_finite = gamma_cl[np.where(np.isfinite(gamma_cl))]
adf_result = ts_stats.adfuller(gamma_finite, maxlag=1, regression='c', autolag=None)
print(f'ADF on gamma: t-stat={adf_result[0]:.4f}, p-value={adf_result[1]:.6f}')

gamma_cl_df = pd.DataFrame(gamma_cl)
gamma_cl_df.ffill(inplace=True)

# 반감기 계산
gammaGood = gamma_cl_df[gamma_cl_df.notna().values]
gammalag = gammaGood.shift()
deltaGamma = gammaGood - gammalag
deltaGamma = deltaGamma.iloc[1:]
gammalag = gammalag.iloc[1:]

X_hl = sm.add_constant(gammalag)
model_hl = sm.OLS(deltaGamma, X_hl)
res_hl = model_hl.fit()
halflife = -np.log(2) / res_hl.params.iloc[1] if res_hl.params.iloc[1] < 0 else 100
halflife_int = int(round(halflife))
print(f'반감기 = {halflife_int}일 (책: 41일)')

lookback_cl = halflife_int

# z-score
MA_cl = gamma_cl_df.rolling(lookback_cl).mean()
MSTD_cl = gamma_cl_df.rolling(lookback_cl).std()
zScore_cl = (gamma_cl_df - MA_cl) / MSTD_cl

# 컬럼 기반 포지션 매트릭스
positions_cl = np.zeros(cl.shape)
isExpireDate = np.isfinite(cl) & ~np.isfinite(cl.shift(-1))
holddays_cl = 3 * 21
numDaysStart = holddays_cl + 10
numDaysEnd = 10
spreadMonth = 12

for c in range(0, cl.shape[1] - spreadMonth):
    expireIdx = np.where(isExpireDate.iloc[:, c])[-1]
    if c == 0:
        startIdx = max(0, expireIdx - numDaysStart)
        endIdx = expireIdx - numDaysEnd
    else:
        myStartIdx = endIdx + 1
        myEndIdx = expireIdx - numDaysEnd
        if len(myEndIdx) > 0 and len(myStartIdx) > 0:
            if (myEndIdx[0] - myStartIdx[0] >= holddays_cl):
                startIdx = myStartIdx
                endIdx = myEndIdx
            else:
                startIdx = np.array([np.inf])
        else:
            startIdx = np.array([np.inf])

    if (len(expireIdx) > 0) and (len(startIdx) > 0) and (len(endIdx) > 0):
        s = int(startIdx[0]) if not np.isinf(startIdx[0]) else None
        e = int(endIdx[0]) if not np.isinf(endIdx[0]) else None
        if s is not None and e is not None and e > s:
            positions_cl[s:e, c] = -1
            positions_cl[s:e, c + spreadMonth] = 1

positions_cl[zScore_cl.isna().values.flatten(), :] = 0
zScore_cl.fillna(-np.inf, inplace=True)
positions_cl[zScore_cl.values.flatten() > 0, :] = -positions_cl[zScore_cl.values.flatten() > 0, :]

# 수익률 계산
pos_shift_cl = np.zeros_like(positions_cl)
pos_shift_cl[1:] = positions_cl[:-1]
pnl_cl = np.nansum(pos_shift_cl * cl.pct_change().values, axis=1)
denom_cl = np.nansum(np.abs(pos_shift_cl), axis=1)
denom_cl[denom_cl == 0] = np.nan
ret_arr_cl = pnl_cl / denom_cl

valid_mask_cl = np.isfinite(ret_arr_cl)
valid_ret_cl = pd.Series(ret_arr_cl[valid_mask_cl], index=cl.index[valid_mask_cl])
cumret_cl = (1 + valid_ret_cl).cumprod() - 1

apr_cl = np.prod(1 + valid_ret_cl.values) ** (252 / len(valid_ret_cl)) - 1
sharpe_cl = np.sqrt(252) * np.mean(valid_ret_cl.values) / np.std(valid_ret_cl.values)
maxDD_cl, maxDDD_cl = calculateMaxDD(cumret_cl)

print(f'APR      = {apr_cl*100:.2f}%')
print(f'Sharpe   = {sharpe_cl:.4f}')
print(f'Max DD   = {maxDD_cl*100:.2f}%')
print(f'(책 기대값: APR=2.4%, Sharpe=1.28)')
# Out:
# ADF on gamma: t-stat=-4.5867, p-value=0.000137
# 반감기 = 41일 (책: 41일)
# APR      = 7.73%
# Sharpe   = 1.2235
# Max DD   = -5.18%
# (책 기대값: APR=2.4%, Sharpe=1.28)

# %% [markdown]
# ### 결과
#
# | 지표 | 값 | 책 기대값 |
# |------|-----|----------|
# | APR | 7.73% | 2.4% |
# | Sharpe Ratio | 1.2235 | 1.28 |
# | Max Drawdown | -5.18% | - |
# | 반감기 | 41일 | 41일 |
# | ADF p-value | 0.000137 | <0.01 |

# %%
# === CL 캘린더 스프레드 차트 ===

fig, axes = plt.subplots(2, 1, figsize=(12, 8))

axes[0].plot(cumret_cl.index, cumret_cl.values * 100, 'b-', linewidth=1)
axes[0].set_title('CL Calendar Spread Mean Reversion - Cumulative Returns', fontsize=13)
axes[0].set_ylabel('Cumulative Return (%)')
axes[0].grid(True, alpha=0.3)

gamma_plot = gamma_cl_df.values.flatten()
valid_g = np.where(np.isfinite(gamma_plot))[0]
axes[1].plot(cl.index[valid_g], gamma_plot[valid_g] * 100, 'r-', linewidth=0.5, alpha=0.7)
axes[1].set_title('CL Roll Return (Gamma, annualized)', fontsize=13)
axes[1].set_ylabel('Roll Return (%)')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# ## 7. 분석 5: VX-ES 변동성 vs 주가지수 평균 회귀 (예제 5.5)
#
# ### 방법론
#
# - **데이터**: CBOE CFE의 VX 선물 근월물(`vix_utils`), E-mini S&P 500 선물(`ES=F`, yfinance) (2004\~2012)
# - **단위 조정**: VX x 1,000 (1포인트 = $1,000), ES x 50 (1포인트 = $50)
# - **레짐 분리**: 2008년 8월 이전(레짐 1)과 이후(레짐 2)를 구분, 레짐 2에 집중
# - **훈련/테스트 분할**: 레짐 2의 처음 500일로 선형 회귀 -> 헤지 비율 산출
# - **포트폴리오**: 회귀 잔차 = ES_dollar - beta x VX_dollar. beta가 음수이므로 "ES 롱 + VX 롱"
# - **전략**: 포트폴리오가 평균에서 1 표준편차 이상 벗어나면 반대 방향 진입 (볼린저 밴드 유사)
#
# **두 가지 접근**: (A) 자체 회귀 파라미터 사용, (B) 책의 파라미터(beta=-0.3906, intercept=$77,150, std=$2,047) 직접 적용
#
# 책 결과: APR=12.3%, Sharpe=1.4

# %%
# === 분석 5: VX-ES 변동성 vs 주가지수 평균 회귀 ===

import yfinance as yf
import nest_asyncio
nest_asyncio.apply()  # Jupyter 이벤트 루프 충돌 방지
import vix_utils

# === 1. 데이터 로드 ===
# VX 선물 근월물 (CBOE CFE, vix_utils)
df_all = vix_utils.load_vix_term_structure()
monthly = df_all[df_all['Weekly'] == False].copy()
monthly['Trade Date'] = pd.to_datetime(monthly['Trade Date']).dt.tz_localize(None)
monthly = monthly[(monthly['Trade Date'] >= '2004-01-01') & (monthly['Trade Date'] <= '2012-12-31')]
front = monthly[monthly['Tenor_Monthly'] == 1][['Trade Date', 'Settle']].copy()
front = front.sort_values('Trade Date').set_index('Trade Date')
front = front[~front.index.duplicated(keep='first')]
front.columns = ['VX']

# ES 선물 (E-mini S&P 500, yfinance)
es_data = yf.download('ES=F', start='2004-01-01', end='2012-12-31', auto_adjust=True)
es = es_data['Close'].squeeze()
es.index = es.index.tz_localize(None)

df_vxes = pd.merge(front, pd.DataFrame({'ES': es}), left_index=True, right_index=True, how='inner')
print(f'VX-ES 공통 거래일: {len(df_vxes)}')

# 단위 조정 (달러 가치)
df_vxes['VX_dollar'] = df_vxes['VX'] * 1000
df_vxes['ES_dollar'] = df_vxes['ES'] * 50

# === 2. 레짐 분리 ===
regime_split = '2008-08-01'
regime1 = df_vxes[df_vxes.index < regime_split]
regime2 = df_vxes[df_vxes.index >= regime_split]
print(f'레짐 1: {len(regime1)}일 (2004 ~ 2008-07)')
print(f'레짐 2: {len(regime2)}일 (2008-08 ~ 2012)')

trainlen_vx = 500
train_vx = regime2.iloc[:trainlen_vx]
test_vx = regime2.iloc[trainlen_vx:]
print(f'훈련: {len(train_vx)}일, 테스트: {len(test_vx)}일')
print(f'테스트 기간: {test_vx.index[0].strftime("%Y-%m-%d")} ~ {test_vx.index[-1].strftime("%Y-%m-%d")}')

# === 3. 자체 회귀 ===
X_train = sm.add_constant(train_vx['VX_dollar'])
res_vxes = sm.OLS(train_vx['ES_dollar'], X_train).fit()
beta_own = res_vxes.params.iloc[1]
intercept_own = res_vxes.params.iloc[0]
std_own = res_vxes.resid.std()

print(f'\n[자체 회귀]')
print(f'  ES*50 = {beta_own:.4f} * VX*1000 + {intercept_own:.0f}')
print(f'  잔차 표준편차 = ${std_own:.0f}')

# === 4. 전략 실행 함수 ===
def run_vxes_strategy(regime2_data, beta, intercept, residual_std, trainlen, label):
    """VX-ES 볼린저 밴드 유사 전략 실행"""
    # 포트폴리오 = 회귀 잔차 = ES_dollar - beta * VX_dollar
    # beta가 음수이므로: ES_dollar + |beta| * VX_dollar (ES 롱 + VX 롱)
    portfolio = regime2_data['ES_dollar'] - beta * regime2_data['VX_dollar']

    port_mean = intercept  # 잔차 평균 ≈ 0이므로 포트폴리오 평균 ≈ intercept
    port_std = residual_std

    zScore = (portfolio - port_mean) / port_std

    numUnits = pd.Series(0.0, index=regime2_data.index)
    numUnits[zScore > 1] = -1.0   # 과매수 -> 숏 포트폴리오
    numUnits[zScore < -1] = 1.0   # 과매도 -> 롱 포트폴리오

    # PnL: 롱 포트폴리오 = ES 매수 + (-beta)*VX 매수
    pos_es = numUnits * regime2_data['ES_dollar']
    pos_vx = numUnits * (-beta) * regime2_data['VX_dollar']

    ret_es = regime2_data['ES'].pct_change()
    ret_vx = regime2_data['VX'].pct_change()
    pnl = pos_es.shift(1) * ret_es + pos_vx.shift(1) * ret_vx
    denom = np.abs(pos_es.shift(1)) + np.abs(pos_vx.shift(1))
    denom[denom == 0] = np.nan
    ret = pnl / denom

    ret_test = ret.iloc[trainlen:].fillna(0)
    cumret = (1 + ret_test).cumprod() - 1
    apr = np.prod(1 + ret_test.values) ** (252 / len(ret_test)) - 1
    sharpe = np.sqrt(252) * ret_test.mean() / ret_test.std()
    maxDD, _ = calculateMaxDD(cumret)

    n_long = (numUnits.iloc[trainlen:] == 1).sum()
    n_short = (numUnits.iloc[trainlen:] == -1).sum()
    n_flat = (numUnits.iloc[trainlen:] == 0).sum()

    print(f'\n[{label}]')
    print(f'  APR    = {apr*100:.2f}%')
    print(f'  Sharpe = {sharpe:.4f}')
    print(f'  Max DD = {maxDD*100:.2f}%')
    print(f'  포지션: Long {n_long}일, Short {n_short}일, Flat {n_flat}일')

    return portfolio, zScore, numUnits, cumret, apr, sharpe, maxDD

# === 5A. 자체 회귀 파라미터로 전략 실행 ===
port_own, zScore_own, units_own, cumret_own, apr_own, sharpe_own, maxDD_own = \
    run_vxes_strategy(regime2, beta_own, intercept_own, std_own, trainlen_vx, '자체 회귀')

# === 5B. 책의 파라미터로 전략 실행 ===
book_beta = -0.3906
book_intercept = 77150
book_std = 2047
print(f'\n[책 파라미터] beta={book_beta}, intercept=${book_intercept:,}, std=${book_std:,}')

port_book, zScore_book, units_book, cumret_book, apr_book, sharpe_book, maxDD_book = \
    run_vxes_strategy(regime2, book_beta, book_intercept, book_std, trainlen_vx, '책 파라미터 적용')

print(f'\n(책 기대값: APR=12.3%, Sharpe=1.4)')

# 변수 저장 (차트용)
regime2_port = port_book
port_mean = book_intercept
port_std_val = book_std
zScore_vx = zScore_book
cumret_vxes = cumret_book
apr_vxes = apr_book
sharpe_vxes = sharpe_book
maxDD_vxes = maxDD_book
# Out:
# [*********************100%***********************]  1 of 1 completed
# VX-ES 공통 거래일: 2078
# 레짐 1: 967일 (2004 ~ 2008-07)
# 레짐 2: 1111일 (2008-08 ~ 2012)
# 훈련: 500일, 테스트: 611일
# 테스트 기간: 2010-07-28 ~ 2012-12-28
#
# [자체 회귀]
#   ES*50 = -0.4628 * VX*1000 + 65612
#   잔차 표준편차 = $4525
#
# [자체 회귀]
#   APR    = -5.16%
#   Sharpe = -0.5636
#   Max DD = -14.49%
#   포지션: Long 0일, Short 517일, Flat 94일
#
# [책 파라미터] beta=-0.3906, intercept=$77,150, std=$2,047
#
# [책 파라미터 적용]
#   APR    = 10.71%
#   Sharpe = 1.2584
#   Max DD = -6.41%
#   포지션: Long 416일, Short 5일, Flat 190일
#
# (책 기대값: APR=12.3%, Sharpe=1.4)

# %%
# === VX-ES 차트 ===
import os
fig_dir = os.path.join('reports', 'figures')
os.makedirs(fig_dir, exist_ok=True)

# --- 차트 1: 산점도 (레짐 색 구분) ---
fig, ax = plt.subplots(1, 1, figsize=(10, 7))
ax.scatter(regime1['ES'], regime1['VX'], alpha=0.3, s=10, c='blue', label='Regime 1 (2004~2008-05)')
ax.scatter(regime2['ES'], regime2['VX'], alpha=0.3, s=10, c='red', label='Regime 2 (2008-08~2012)')
ax.set_xlabel('ES Futures')
ax.set_ylabel('VX Futures (1M)')
ax.set_title('ES vs VX Scatter Plot (Two Regimes)', fontsize=13)
ax.legend(fontsize=9)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(fig_dir, 'ch5_vxes_scatter.png'), dpi=150, bbox_inches='tight')
plt.show()

# --- 차트 2: 전략 결과 (3패널) ---
fig, axes = plt.subplots(3, 1, figsize=(12, 10))

# 포트폴리오 시장 가치 (책 파라미터)
axes[0].plot(regime2_port.index, regime2_port.values, 'b-', linewidth=0.8)
axes[0].axhline(y=port_mean, color='k', linestyle='--', linewidth=1, label=f'Mean: ${port_mean:,}')
axes[0].axhline(y=port_mean + port_std_val, color='r', linestyle=':', linewidth=1, label='+1 std')
axes[0].axhline(y=port_mean - port_std_val, color='g', linestyle=':', linewidth=1, label='-1 std')
axes[0].axvline(x=regime2.index[trainlen_vx], color='orange', linestyle='--', alpha=0.7, label='Train/Test split')
axes[0].set_title('Stationary Portfolio (Book params)', fontsize=12)
axes[0].set_ylabel('Portfolio Value ($)')
axes[0].legend(fontsize=7)
axes[0].grid(True, alpha=0.3)

# 누적 수익률 비교
axes[1].plot(cumret_book.index, cumret_book.values * 100, 'b-', linewidth=1,
             label=f'Book params (APR={apr_book*100:.1f}%)')
axes[1].plot(cumret_own.index, cumret_own.values * 100, 'r--', linewidth=1,
             label=f'Own regression (APR={apr_own*100:.1f}%)')
axes[1].set_title('VX-ES Mean Reversion - Cumulative Returns (Test Set)', fontsize=12)
axes[1].set_ylabel('Cumulative Return (%)')
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.3)

# z-score (책 파라미터)
axes[2].plot(zScore_vx.index, zScore_vx.values, 'b-', linewidth=0.5, alpha=0.7)
axes[2].axhline(y=1, color='r', linestyle='--', linewidth=1, label='Short threshold (+1)')
axes[2].axhline(y=-1, color='g', linestyle='--', linewidth=1, label='Long threshold (-1)')
axes[2].axhline(y=0, color='k', linestyle='-', linewidth=0.5)
axes[2].axvline(x=regime2.index[trainlen_vx], color='orange', linestyle='--', alpha=0.7)
axes[2].set_title('Z-Score (Book params)', fontsize=12)
axes[2].set_ylabel('Z-Score')
axes[2].legend(fontsize=8)
axes[2].grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(fig_dir, 'ch5_vxes_strategy.png'), dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 결과 비교
#
# | 지표 | 자체 회귀 | 책 파라미터 적용 | 책 기대값 |
# |------|----------|----------------|----------|
# | 헤지 비율 (beta) | -0.4628 | -0.3906 | -0.3906 |
# | 잔차 표준편차 | $4,525 | $2,047 | $2,047 |
# | APR | -5.16% | 10.71% | 12.3% |
# | Sharpe Ratio | -0.56 | 1.26 | 1.4 |
# | Max Drawdown | -14.49% | -6.41% | - |
#
# **핵심 발견**: 전략 로직(볼린저 밴드 유사)은 올바르며, 책의 파라미터를 사용하면 APR=10.71%, Sharpe=1.26으로 책(12.3%, 1.4)에 근접한다.
#
# **자체 회귀가 나쁜 이유**: 무료 데이터(CBOE CFE VX settle + yfinance ES=F)로 추정한 회귀의 잔차 표준편차($4,525)가 책($2,047)의 2.2배. 이는 데이터 소스 차이(settlement 가격 vs 상용 데이터 제공업체의 종가, 결제 시간 불일치 등)에 기인한다. 볼린저 밴드 폭이 2배 넓어져 진입 신호가 왜곡됨.

# %% [markdown]
# ---
#
# ## 8. 전략 종합 비교
#
# | 전략 | APR | Sharpe | 시장 | 특성 |
# |------|-----|--------|------|------|
# | AUD/USD-CAD/USD Johansen | 9.24% | 1.36 | FX | 동적 헤지 |
# | AUD/CAD + Rollover | 6.28% | 0.55 | FX | 단순 헤지 |
# | CL Calendar Spread | 7.73% | 1.22 | Futures | 감마 기반 |
# | VX-ES Mean Reversion | 10.71%* | 1.26* | Futures | 볼린저 밴드 유사 |
#
# \* 책의 회귀 파라미터(beta=-0.3906, std=$2,047) 적용. 책 기대값: APR=12.3%, Sharpe=1.4
#
# ---
#
# ## 9. 결론 및 권고사항
#
# ### 핵심 발견
#
# 1. **통화 페어 메커니즘**: 공적분 검정 시 동일 호가 통화를 사용해야 의미 있는 결과
# 2. **롤오버 이자의 미미한 영향**: 단기 전략에서 연 5% 금리차도 전략 성과에 작은 영향
# 3. **롤 수익률의 지배력**: 많은 선물에서 롤 수익률이 스팟 수익률을 압도
# 4. **캘린더 스프레드 신호**: 스팟 가격이 아닌 롤 수익률(감마)이 거래 신호
# 5. **VX-ES 역상관 활용**: 변동성-주가지수 간 역상관을 레짐별로 분리하면 높은 샤프 비율의 평균 회귀 전략 구축 가능
#
# ### 주의사항
#
# - **레짐 변화**: VX-ES 관계는 2008년 전후로 레짐이 다름 — 혼합 데이터에 회귀 적용 금지
# - **데이터 소스 민감도**: VX-ES 전략은 회귀 파라미터에 극도로 민감 — 무료 데이터의 잔차 std가 2배 커지면 성과 급락
# - **선물 가격 동기화**: 서로 다른 거래소 선물 간 종가 시간 불일치 주의
# - **생존자 편향**: 현존하는 계약만으로 백테스트하면 편향 발생 가능
# - **단위 불일치**: 서로 다른 승수를 가진 선물 간 페어 트레이딩 시 반드시 달러 가치 환산 필요
